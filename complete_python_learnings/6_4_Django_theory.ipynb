# %% [markdown]
# ## What is Django?
# #### Django is a high-level Python web framework that enables rapid development of secure and maintainable websites. Built by experienced developers, Django takes care of much of the hassle of web development, so you can focus on writing your app without needing to reinvent the wheel.
# #### It follows MVT(Model View Template) Architecture.
# ![download.png](attachment:download.png)

# %% [markdown]
# # run anaconda propmt in administartor mode :
# ## installing Django : python -m pip install Django
# #### you can install in any environment (to create new env : conda env -n (env name) and conda activate (env name)

# %% [markdown]
# ## create a new file to store all in one file :
# ###              mkdir filename
# ####               eg: mkdir test1
# ### get inside test1 :
# ###               cd test1

# %% [markdown]
# ## creating a new project :
# ###             django-admin startproject (projectname)
# ####              eg, django-admin startproject project1
# ![download.png](attachment:download.png)

# %% [markdown]
# ## get inside project :
# ###              cd (projectname)
# ####                eg, cd project1
# ![download.png](attachment:download.png)

# %% [markdown]
# ## start a server :
# ###                python manage.py runserver
# ### (manage.py file automatically created in project folder)

# %% [markdown]
# ### copy the url and paste in google and run
# ![Screenshot_20221018_125641.png](attachment:Screenshot_20221018_125641.png)

# %% [markdown]
# ### the website looks like this, says install worked successfully
# ![Screenshot_20221017_054917.png](attachment:Screenshot_20221017_054917.png)

# %% [markdown]
# ## to create a new app called hello_app :
# ### python manage.py startapp hello_app

# %% [markdown]
# ![Screenshot_20221018_025107.png](attachment:Screenshot_20221018_025107.png)
